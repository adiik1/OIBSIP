# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
iris_rd= pd.read_csv(r"C:\Users\wappu\Downloads\archive\Iris.csv")

# %%
iris_rd.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_rd.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris_rd.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_rd.shape
# Out:
# (150, 6)

# %%
iris_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_rd.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_rd.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_rd.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(iris_rd,hue='Species')

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.scatterplot(x='SepalLengthCm', y='PetalLengthCm', data=iris_rd, hue='Species') 

plt.subplot(1,2,2)
sns.scatterplot(x='SepalLengthCm', y='PetalLengthCm', data=iris_rd, hue='Species') 
plt.show()

# %%
iris_rd["Species"].value_counts().plot(kind="pie",autopct = "%1.1f%%",shadow=True,figsize=(5,5)) 
plt.title("Percentage values in each species",fontsize=12, c = "g") 
plt.ylabel("",fontsize=10,c="r")

plt.show()

# %%
iris_rd_enc = pd.get_dummies(iris_rd, columns=['Species'])
correlation = iris_rd_enc.corr()
correlation
# Out:
#                                    Id  SepalLengthCm  SepalWidthCm  \
# Id                       1.000000e+00       0.716676     -0.397729
# SepalLengthCm            7.166763e-01       1.000000     -0.109369
# SepalWidthCm            -3.977288e-01      -0.109369      1.000000
# PetalLengthCm            8.827473e-01       0.871754     -0.420516
# PetalWidthCm             8.997586e-01       0.817954     -0.356544
# Species_Iris-setosa     -8.165147e-01      -0.717416      0.595601
# Species_Iris-versicolor -3.481012e-18       0.079396     -0.464700
# Species_Iris-virginica   8.165147e-01       0.638020     -0.130901
#
#                          PetalLengthCm  PetalWidthCm  Species_Iris-setosa  \
# Id                            0.882747      0.899759            -0.816515
# SepalLengthCm                 0.871754      0.817954            -0.717416
# SepalWidthCm                 -0.420516     -0.356544             0.595601
# ...

# %%
sns.heatmap(correlation,annot=True)
plt.show()

# %%
sns.jointplot(data=iris_rd , x='SepalLengthCm', y='PetalLengthCm', size=7, hue='Species')
plt.show()

# %% [markdown]
# ## Training Data

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
iris_rd["Species"]=l.fit_transform(iris_rd["Species"])
iris_rd.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
x=iris_rd.iloc[:,[0,1,2,3]]
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0   1            5.1           3.5            1.4
# 1   2            4.9           3.0            1.4
# 2   3            4.7           3.2            1.3
# 3   4            4.6           3.1            1.5
# 4   5            5.0           3.6            1.4

# %%
y=iris_rd.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.5,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (75, 4)
# (75, 4)
# (75,)
# (75,)

# %%
from sklearn.linear_model import LogisticRegression
z=LogisticRegression()
z.fit(x_train , y_train)
y_pred=z.predict(x_test)

# %%
from sklearn.metrics import classification_report

print("Classification Report:")
print(classification_report(y_test,y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        21
#            1       1.00      1.00      1.00        30
#            2       1.00      1.00      1.00        24
#
#     accuracy                           1.00        75
#    macro avg       1.00      1.00      1.00        75
# weighted avg       1.00      1.00      1.00        75

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print("Confusion Matrix")
print(confusion_matrix(y_test,y_pred))
print("\n")
print("Accuracy is:")
print(accuracy_score(y_test,y_pred)*100)
# Out:
# Confusion Matrix
# [[21  0  0]
#  [ 0 30  0]
#  [ 0  0 24]]
#
#
# Accuracy is:
# 100.0
